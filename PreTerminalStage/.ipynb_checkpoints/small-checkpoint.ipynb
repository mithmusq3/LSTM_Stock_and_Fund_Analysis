# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# For reading stock data from yahoo
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr

yf.pdr_override()
# For time stamps
from datetime import datetime


# The tech stocks we'll use for this analysis
tech_list = ['']
# Set up End and Start times for data grab

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)
i = 1
for stock in tech_list:
    val = 'f' + str(i)
    globals()[val] = yf.download(stock, start='2012-01-01', end=datetime.now())
    i = i + 1

company_list = ['']*(i-1)
k=1
for x in company_list:
    company_list[k-1] = eval('f' + str(k))
    k = k + 1 
#print(company_list)
company_name = ["Aditya Birla Sun Life Frontline Equity Fund","Axis Bluechip Fund","Baroda BNP Paribas Large Cap Fund","Canara Robeco Bluechip Equity Fund","Canara Robeco Bluechip Equity Fund","DSP Top 100 Equity Fund","Edelweiss Large Cap Fund","Franklin India Bluechip Fund","HDFC Top 100 Fund","ICICI Prudential Bluechip Fund","IDBI India Top 100 Equity","IDFC Large Cap Fund","Invesco India Largecap Fund","ITI Large Cap Fund","JM Large Cap Fund","LIC MF Large Cap Fund","Mirae Asset Large Cap Fund","Nippon India Large Cap Fund","PGIM India Large Cap Fund","SBI Bluechip Fund","Sundaram Large Cap Fund","Tata Large Cap Fund","Taurus Largecap Equity Fund","Union Largecap Fund","UTI Mastershare Fund"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(300)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume  \
# Date
# 2022-01-03  17.570000  17.570000  17.570000  17.570000  17.570000       0
# 2022-01-04  17.700001  17.700001  17.700001  17.700001  17.700001       0
# 2022-01-05  17.770000  17.770000  17.770000  17.770000  17.770000       0
# 2022-01-06  17.629999  17.629999  17.629999  17.629999  17.629999       0
# 2022-01-07  17.690001  17.690001  17.690001  17.690001  17.690001       0
# ...               ...        ...        ...        ...        ...     ...
# 2023-03-13  16.450001  16.450001  16.450001  16.450001  16.450001       0
# 2023-03-14  16.389999  16.389999  16.389999  16.389999  16.389999       0
# 2023-03-15  16.309999  16.309999  16.309999  16.309999  16.309999       0
# 2023-03-16  16.330000  16.330000  16.330000  16.330000  16.330000       0
# 2023-03-17  16.420000  16.420000  16.420000  16.420000  16.420000       0
#
#                    company_name
# Date
# 2022-01-03  Union Largecap Fund
# 2022-01-04  Union Largecap Fund
# 2022-01-05  Union Largecap Fund
# 2022-01-06  Union Largecap Fund
# 2022-01-07  Union Largecap Fund
# ...                         ...
# 2023-03-13  Union Largecap Fund
# 2023-03-14  Union Largecap Fund
# 2023-03-15  Union Largecap Fund
# 2023-03-16  Union Largecap Fund
# 2023-03-17  Union Largecap Fund
#
# [300 rows x 7 columns]

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Scale the data
from sklearn.preprocessing import MinMaxScaler

for i, company in enumerate(company_list, 1):
    # Create a new dataframe with only the 'Close column 
    data = company.filter(['Close'])
    # Convert the dataframe to a numpy array
    dataset = data.values
    # Get the number of rows to train the model on
    training_data_len = int(np.ceil( len(dataset) * .95 ))
    print(str(i)+'. ')
    print(company_name[i-1])
    print(training_data_len)
    print("\n")
    scaler = MinMaxScaler(feature_range=(0,1))
    scaled_data = scaler.fit_transform(dataset)

    # scaled_data
    # Create the training data set 
    # Create the scaled training data set
    train_data = scaled_data[0:int(training_data_len), :]
    # Split the data into x_train and y_train data sets
    x_train = []
    y_train = []

    for i in range(60, len(train_data)):
        x_train.append(train_data[i-60:i, 0])
        y_train.append(train_data[i, 0])
        if i<= 61:
            ko=1
            #print(x_train)
            #print(y_train)
            #print()

    # Convert the x_train and y_train to numpy arrays 
    x_train, y_train = np.array(x_train), np.array(y_train)

    # Reshape the data
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    # x_train.shape

    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
    model.add(LSTM(64, return_sequences=False))
    model.add(Dense(25))
    model.add(Dense(1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    model.fit(x_train, y_train, batch_size=1, epochs=1)
    # Create the testing data set
    # Create a new array containing scaled values from index 1543 to 2002 
    test_data = scaled_data[training_data_len - 60: , :]
    # Create the data sets x_test and y_test
    x_test = []
    y_test = dataset[training_data_len:, :]
    for i in range(60, len(test_data)):
        x_test.append(test_data[i-60:i, 0])

    # Convert the data to a numpy array
    x_test = np.array(x_test)

    # Reshape the data
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

    # Get the models predicted price values 
    predictions = model.predict(x_test)
    predictions = scaler.inverse_transform(predictions)
    mape = (np.mean(abs((y_test-predictions)/y_test)))*100
    print("Mean Absolute Percentage Error: ")
    print(mape)
    print("\n")
    mae = (np.mean(abs(y_test-predictions)))
    print("Mean Absolute Error: ")
    print(mae)
    print("\n")
    # Get the root mean squared error (RMSE)
    rmse = np.sqrt(np.mean((((y_test - predictions)/y_test) ** 2)))
    print("Root mean square error: ")
    print(rmse)
    print("\n")
    mse = (np.mean((y_test-predictions)**2))
    print("Mean Squared Error: ")
    print(mse)
    print("\n")
# Out:
# 1.
# Aditya Birla Sun Life Frontline Equity Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 36ms/step - loss: 0.0022
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001AE09CE7640> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 80ms/step
# Mean Absolute Percentage Error:
# 3.1863694953544166
#
#
# Mean Absolute Error:
# 11.01107931137085
#
#
# Root mean square error:
# 0.03375159136496368
#
#
# Mean Squared Error:
# 135.1875795780943
#
#
# 2.
# Axis Bluechip Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 36ms/step - loss: 0.0033
# 2/2 [==============================] - 1s 56ms/step
# Mean Absolute Percentage Error:
# 0.9690004254412764
#
#
# Mean Absolute Error:
# 0.4135012626647949
#
#
# Root mean square error:
# 0.011519437418556338
#
#
# Mean Squared Error:
# 0.24229274440040172
#
#
# 3.
# Baroda BNP Paribas Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 37ms/step - loss: 0.0026
# 2/2 [==============================] - 1s 74ms/step
# Mean Absolute Percentage Error:
# 2.234480829686187
#
#
# Mean Absolute Error:
# 3.5691709518432617
#
#
# Root mean square error:
# 0.024735106581600684
#
#
# Mean Squared Error:
# 15.501997612584091
#
#
# 4.
# Canara Robeco Bluechip Equity Fund
# 1220
#
#
# 1160/1160 [==============================] - 48s 37ms/step - loss: 0.0024
# 2/2 [==============================] - 1s 81ms/step
# Mean Absolute Percentage Error:
# 4.051251138937564
#
#
# Mean Absolute Error:
# 1.6835922002792358
#
#
# Root mean square error:
# 0.0416151847807656
#
#
# Mean Squared Error:
# 3.001228430662195
#
#
# 5.
# Canara Robeco Bluechip Equity Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 36ms/step - loss: 0.0040
# 2/2 [==============================] - 1s 71ms/step
# Mean Absolute Percentage Error:
# 1.2836493764951635
#
#
# Mean Absolute Error:
# 3.729823589324951
#
#
# Root mean square error:
# 0.01582083162799894
#
#
# Mean Squared Error:
# 20.945184443189646
#
#
# 6.
# DSP Top 100 Equity Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 37ms/step - loss: 0.0028
# 2/2 [==============================] - 1s 59ms/step
# Mean Absolute Percentage Error:
# 1.219951763980672
#
#
# Mean Absolute Error:
# 0.6847115159034729
#
#
# Root mean square error:
# 0.014322352747878719
#
#
# Mean Squared Error:
# 0.6487778074972539
#
#
# 7.
# Edelweiss Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 36ms/step - loss: 0.0029
# 2/2 [==============================] - 1s 75ms/step
# Mean Absolute Percentage Error:
# 0.7876782752000757
#
#
# Mean Absolute Error:
# 5.851446151733398
#
#
# Root mean square error:
# 0.009582499512289453
#
#
# Mean Squared Error:
# 50.29518355673645
#
#
# 8.
# Franklin India Bluechip Fund
# 1220
#
#
# 1160/1160 [==============================] - 46s 36ms/step - loss: 0.0023
# 2/2 [==============================] - 1s 53ms/step
# Mean Absolute Percentage Error:
# 2.5661965970879796
#
#
# Mean Absolute Error:
# 19.136452674865723
#
#
# Root mean square error:
# 0.02831968251192084
#
#
# Mean Squared Error:
# 442.93514348362805
#
#
# 9.
# HDFC Top 100 Fund
# 1220
#
#
# 1160/1160 [==============================] - 46s 36ms/step - loss: 0.0023
# 2/2 [==============================] - 1s 72ms/step
# Mean Absolute Percentage Error:
# 2.9909270677685487
#
#
# Mean Absolute Error:
# 2.054248332977295
#
#
# Root mean square error:
# 0.03151516514483465
#
#
# Mean Squared Error:
# 4.6591488665108045
#
#
# 10.
# ICICI Prudential Bluechip Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 36ms/step - loss: 0.0030
# 2/2 [==============================] - 1s 74ms/step
# Mean Absolute Percentage Error:
# 1.0046136255192757
#
#
# Mean Absolute Error:
# 0.396938681602478
#
#
# Root mean square error:
# 0.012789428505537714
#
#
# Mean Squared Error:
# 0.25105848966313715
#
#
# 11.
# IDBI India Top 100 Equity
# 1220
#
#
# 1160/1160 [==============================] - 47s 36ms/step - loss: 0.0023
# 2/2 [==============================] - 1s 76ms/step
# Mean Absolute Percentage Error:
# 1.5766616905760324
#
#
# Mean Absolute Error:
# 0.849723219871521
#
#
# Root mean square error:
# 0.019133334706170804
#
#
# Mean Squared Error:
# 1.0540026980688708
#
#
# 12.
# IDFC Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 37ms/step - loss: 0.0034
# 2/2 [==============================] - 1s 68ms/step
# Mean Absolute Percentage Error:
# 2.76902450067956
#
#
# Mean Absolute Error:
# 1.186152696609497
#
#
# Root mean square error:
# 0.03029654668078433
#
#
# Mean Squared Error:
# 1.6722523261901188
#
#
# 13.
# Invesco India Largecap Fund
# 525
#
#
# 465/465 [==============================] - 22s 37ms/step - loss: 0.0095
# 1/1 [==============================] - 1s 1s/step
# Mean Absolute Percentage Error:
# 1.1908099425810816
#
#
# Mean Absolute Error:
# 0.13964119663944952
#
#
# Root mean square error:
# 0.014122451873556879
#
#
# Mean Squared Error:
# 0.02714890812081581
#
#
# 14.
# ITI Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 48s 37ms/step - loss: 0.0031
# 2/2 [==============================] - 1s 71ms/step
# Mean Absolute Percentage Error:
# 2.0037405173342444
#
#
# Mean Absolute Error:
# 2.0242342948913574
#
#
# Root mean square error:
# 0.02267526272755484
#
#
# Mean Squared Error:
# 5.192103039560607
#
#
# 15.
# JM Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 37ms/step - loss: 0.0029
# 2/2 [==============================] - 2s 61ms/step
# Mean Absolute Percentage Error:
# 1.788697129595531
#
#
# Mean Absolute Error:
# 0.7142391204833984
#
#
# Root mean square error:
# 0.020131388043178596
#
#
# Mean Squared Error:
# 0.6486483750286425
#
#
# 16.
# LIC MF Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 48s 37ms/step - loss: 0.0036
# 2/2 [==============================] - 1s 89ms/step
# Mean Absolute Percentage Error:
# 2.700873686511327
#
#
# Mean Absolute Error:
# 2.1207932233810425
#
#
# Root mean square error:
# 0.029341495009252986
#
#
# Mean Squared Error:
# 5.264818777522123
#
#
# 17.
# Mirae Asset Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 37ms/step - loss: 0.0021
# 2/2 [==============================] - 1s 81ms/step
# Mean Absolute Percentage Error:
# 3.507551314174648
#
#
# Mean Absolute Error:
# 1.9157852530479431
#
#
# Root mean square error:
# 0.03680906200232964
#
#
# Mean Squared Error:
# 4.0203468820675425
#
#
# 18.
# Nippon India Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 48s 37ms/step - loss: 0.0026
# 2/2 [==============================] - 1s 66ms/step
# Mean Absolute Percentage Error:
# 0.8133735943303074
#
#
# Mean Absolute Error:
# 0.14773863554000854
#
#
# Root mean square error:
# 0.010188695193517849
#
#
# Mean Squared Error:
# 0.034043823751517266
#
#
# 19.
# PGIM India Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 48s 37ms/step - loss: 0.0026
# 2/2 [==============================] - 1s 75ms/step
# Mean Absolute Percentage Error:
# 1.6280456671395886
#
#
# Mean Absolute Error:
# 1.1241456270217896
#
#
# Root mean square error:
# 0.018174634797746416
#
#
# Mean Squared Error:
# 1.5802143964019706
#
#
# 20.
# SBI Bluechip Fund
# 575
#
#
# 515/515 [==============================] - 24s 37ms/step - loss: 0.0061
# 1/1 [==============================] - 1s 1s/step
# Mean Absolute Percentage Error:
# 3.205842978457308
#
#
# Mean Absolute Error:
# 0.4733599662780762
#
#
# Root mean square error:
# 0.03447580205082377
#
#
# Mean Squared Error:
# 0.25641589754016725
#
#
# 21.
# Sundaram Large Cap Fund
# 1188
#
#
# 1128/1128 [==============================] - 47s 37ms/step - loss: 0.0033
# 2/2 [==============================] - 1s 95ms/step
# Mean Absolute Percentage Error:
# 4.087492114766925
#
#
# Mean Absolute Error:
# 13.749082995999244
#
#
# Root mean square error:
# 0.04248633426082145
#
#
# Mean Squared Error:
# 203.1832517674343
#
#
# 22.
# Tata Large Cap Fund
# 1220
#
#
# 1160/1160 [==============================] - 47s 36ms/step - loss: 0.0026
# 2/2 [==============================] - 2s 78ms/step
# Mean Absolute Percentage Error:
# 1.7181194287789123
#
#
# Mean Absolute Error:
# 1.7431532144546509
#
#
# Root mean square error:
# 0.021901488421007153
#
#
# Mean Squared Error:
# 4.874207413989097
#
#
# 23.
# Taurus Largecap Equity Fund
# 1220
# 1160/1160 [==============================] - 47s 36ms/step - loss: 0.0031
# 2/2 [==============================] - 1s 63ms/step
# Mean Absolute Percentage Error:
# 1.1751985143719907
#
#
# Mean Absolute Error:
# 0.19916272163391113
#
#
# Root mean square error:
# 0.0151295917576965
#
#
# Mean Squared Error:
# 0.06496404772201458
#
#
# 24.
# Union Largecap Fund
# 1220
#
#
# 1160/1160 [==============================] - 48s 37ms/step - loss: 0.0034
# 2/2 [==============================] - 1s 64ms/step
# Mean Absolute Percentage Error:
# 2.238491452277136
#
#
# Mean Absolute Error:
# 0.3845095634460449
#
#
# Root mean square error:
# 0.024591222393902056
#
#
# Mean Squared Error:
# 0.17898893853191566
